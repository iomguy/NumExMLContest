# %%
import pandas as pd
import catboost
import numpy as np
import tqdm
from sklearn.model_selection import KFold
from catboost import CatBoostRegressor, FeaturesData, Pool
from matplotlib import pyplot as plt

best_combinations_amount = 10
number_of_tests = 400
common_best_combinations_list = []

for i in tqdm.tqdm_notebook(range(number_of_tests)):
    data_train = pd.read_csv("Results(4000).csv", engine='python', encoding="windows-1251", sep=";", index_col=False,
                             skiprows=2)
    # cols = ["Well_type"]
    # cols_indexes = [data_train.columns.get_loc(c) for c in data_train.columns if c in cols]
    # NNS = data_train.loc[data_train ['column_name'] == some_value]
    nns = data_train.loc[data_train["Well_type"] == 1]
    nns_grp = data_train.loc[data_train["Well_type"] == 2]
    gs = data_train.loc[data_train["Well_type"] == 3]
    gs_grp = data_train.loc[data_train["Well_type"] == 4]
    
    nns_numeric_features_names = ["PSS", "Pprod", "Pinj", "Perm", "h", "a/b", "Poro", "Sw", "VdP", "Pbp", "mo",
                                  "Bo", "po", "mw", "Bw", "Pres"]
    nns_features = nns[nns_numeric_features_names]
    nns_target = nns[["NPV"]]

    nns_grp_numeric_features_names = ["PSS", "Pprod", "Pinj", "Perm", "h", "a/b", "Poro", "Sw", "VdP", "Pbp", "mo",
                                      "Bo", "po", "mw", "Bw", "Pres",
                                      "Lfracprod", "Lfracinj", "Frac_perm", "Wprod", "Winj"]
    nns_grp_features = nns_grp[nns_grp_numeric_features_names]
    nns_grp_target = nns_grp[["NPV"]]

    gs_numeric_features_names = ["PSS", "Pprod", "Pinj", "Perm", "h", "a/b", "Poro", "Sw", "VdP", "Pbp", "mo",
                                  "Bo", "po", "mw", "Bw", "Pres", "Lgsprod", "Lgsinj"]
    gs_features = gs[gs_numeric_features_names]
    gs_target = gs[["NPV"]]

    gs_grp_numeric_features_names = ["PSS", "Pprod", "Pinj", "Perm", "h", "a/b", "Poro", "Sw", "VdP", "Pbp", "mo",
                                      "Bo", "po", "mw", "Bw", "Pres",
                                     "Lfracprod", "Lfracinj", "Frac_perm", "Wprod", "Winj",
                                     "Lgsprod", "Lgsinj", "Nfracprod", "Nfracinj"]
    gs_grp_features = gs_grp[gs_grp_numeric_features_names]
    gs_grp_target = gs_grp[["NPV"]]
    
    # train/test division
    skf = KFold(n_splits=9, shuffle=True)
    # range(1) stops "for" after the 1-st iteration
    for _, (nns_train_index, nns_test_index) \
            in zip(range(1), skf.split(np.array(nns_features), np.array(nns_features))):
        # nns_target.iloc[test_index, :]
        nns_features_train, nns_features_test =\
            nns_features.values[nns_train_index], nns_features.values[nns_test_index]
        nns_target_train, nns_target_test = \
            nns_target.values[nns_train_index], nns_target.values[nns_test_index]

    print("nns train: {}".format(nns_features_train.shape))
    print("nns test: {}".format(nns_features_test.shape))

    for _, (nns_grp_train_index, nns_grp_test_index) \
            in zip(range(1), skf.split(np.array(nns_grp_features), np.array(nns_grp_features))):
        # nns_grp_target.iloc[test_index, :]
        nns_grp_features_train, nns_grp_features_test = \
            nns_grp_features.values[nns_grp_train_index], nns_grp_features.values[nns_grp_test_index]
        nns_grp_target_train, nns_grp_target_test = \
            nns_grp_target.values[nns_grp_train_index], nns_grp_target.values[nns_grp_test_index]

    for _, (gs_train_index, gs_test_index) \
            in zip(range(1), skf.split(np.array(gs_features), np.array(gs_features))):
        # gs_target.iloc[test_index, :]
        gs_features_train, gs_features_test = \
            gs_features.values[gs_train_index], gs_features.values[gs_test_index]
        gs_target_train, gs_target_test = \
            gs_target.values[gs_train_index], gs_target.values[gs_test_index]

    for _, (gs_grp_train_index, gs_grp_test_index) \
            in zip(range(1), skf.split(np.array(gs_grp_features), np.array(gs_grp_features))):
        # gs_grp_target.iloc[test_index, :]
        gs_grp_features_train, gs_grp_features_test = \
            gs_grp_features.values[gs_grp_train_index], gs_grp_features.values[gs_grp_test_index]
        gs_grp_target_train, gs_grp_target_test = \
            gs_grp_target.values[gs_grp_train_index], gs_grp_target.values[gs_grp_test_index]
        
    nns_model = CatBoostRegressor(iterations=400, learning_rate=0.6, depth=6, name="nns", loss_function='RMSE', eval_metric="MAE")
    nns_train_pool = catboost.Pool(nns_features_train.astype(np.float32), nns_target_train[:,0].astype(np.float32))
    nns_validate_pool = catboost.Pool(nns_features_test.astype(np.float32), nns_target_test[:,0].astype(np.float32))
    nns_model.fit(nns_train_pool, eval_set=nns_validate_pool, verbose=False, plot=False, use_best_model=True)
    
    nns_grp_model = CatBoostRegressor(iterations=400, learning_rate=0.6, depth=6, name="nns_grp", loss_function='RMSE', eval_metric="MAE")
    nns_grp_train_pool = catboost.Pool(nns_grp_features_train.astype(np.float32), nns_grp_target_train[:,0].astype(np.float32))
    nns_grp_validate_pool = catboost.Pool(nns_grp_features_test.astype(np.float32), nns_grp_target_test[:,0].astype(np.float32))
    nns_grp_model.fit(nns_grp_train_pool, eval_set=nns_grp_validate_pool, verbose=False, plot=False, use_best_model=True)

    gs_model = CatBoostRegressor(iterations=400, learning_rate=0.6, depth=6, name="gs", loss_function='RMSE', eval_metric="MAE")
    gs_train_pool = catboost.Pool(gs_features_train.astype(np.float32), gs_target_train[:,0].astype(np.float32))
    gs_validate_pool = catboost.Pool(gs_features_test.astype(np.float32), gs_target_test[:,0].astype(np.float32))
    gs_model.fit(gs_train_pool, eval_set=gs_validate_pool, verbose=False, plot=False, use_best_model=True)

    gs_grp_model = CatBoostRegressor(iterations=400, learning_rate=0.6, depth=6, name="gs_grp", loss_function='RMSE', eval_metric="MAE")
    gs_grp_train_pool = catboost.Pool(gs_grp_features_train.astype(np.float32), gs_grp_target_train[:,0].astype(np.float32))
    gs_grp_validate_pool = catboost.Pool(gs_grp_features_test.astype(np.float32), gs_grp_target_test[:,0].astype(np.float32))
    gs_grp_model.fit(gs_grp_train_pool, eval_set=gs_grp_validate_pool, verbose=False, plot=False, use_best_model=True)

    common_best_combinations_amounts = []
    
    print("nns best npv combination")
    arr = pd.DataFrame(np.column_stack((nns_model.predict(nns_validate_pool), nns_target_test[:,0])))
    print("NumEX:")
    best_npv_combination_NumEX = np.sort(((arr.sort_values([0], ascending=False))[0:best_combinations_amount]).index)
    print(best_npv_combination_NumEX)
    print("ML:")
    best_npv_combination_ML = np.sort(((arr.sort_values([1], ascending=False))[0:best_combinations_amount]).index)
    print(best_npv_combination_ML)
    print("Common combinations:")
    common_best_combinations = set(best_npv_combination_NumEX).intersection(set(best_npv_combination_ML))
    print("{0} from {1}".format(len(common_best_combinations), best_combinations_amount))    
    common_best_combinations_amounts.append(len(common_best_combinations))
    
    print("nns_grp best npv combination")
    arr = pd.DataFrame(np.column_stack((nns_grp_model.predict(nns_grp_validate_pool), nns_grp_target_test[:,0])))
    print("NumEX:")
    best_npv_combination_NumEX = np.sort(((arr.sort_values([0], ascending=False))[0:best_combinations_amount]).index)
    print(best_npv_combination_NumEX)
    print("ML:")
    best_npv_combination_ML = np.sort(((arr.sort_values([1], ascending=False))[0:best_combinations_amount]).index)
    print(best_npv_combination_ML)
    print("Common combinations:")
    common_best_combinations = set(best_npv_combination_NumEX).intersection(set(best_npv_combination_ML))
    print("{0} from {1}".format(len(common_best_combinations), best_combinations_amount))
    common_best_combinations_amounts.append(len(common_best_combinations))
    
    print("gs best npv combination")

    arr = pd.DataFrame(np.column_stack((gs_model.predict(gs_validate_pool), gs_target_test[:,0])))
    print("NumEX:")
    best_npv_combination_NumEX = np.sort(((arr.sort_values([0], ascending=False))[0:best_combinations_amount]).index)
    print(best_npv_combination_NumEX)
    print("ML:")
    best_npv_combination_ML = np.sort(((arr.sort_values([1], ascending=False))[0:best_combinations_amount]).index)
    print(best_npv_combination_ML)
    print("Common combinations:")
    common_best_combinations = set(best_npv_combination_NumEX).intersection(set(best_npv_combination_ML))
    print("{0} from {1}".format(len(common_best_combinations), best_combinations_amount))
    common_best_combinations_amounts.append(len(common_best_combinations))
    
    print("gs_grp best npv combination")
    arr = pd.DataFrame(np.column_stack((gs_grp_model.predict(gs_grp_validate_pool), gs_grp_target_test[:,0])))
    print("NumEX:")
    best_npv_combination_NumEX = np.sort(((arr.sort_values([0], ascending=False))[0:best_combinations_amount]).index)
    print(best_npv_combination_NumEX)
    print("ML:")
    best_npv_combination_ML = np.sort(((arr.sort_values([1], ascending=False))[0:best_combinations_amount]).index)
    print(best_npv_combination_ML)
    print("Common combinations:")
    common_best_combinations = set(best_npv_combination_NumEX).intersection(set(best_npv_combination_ML))
    print("{0} from {1}".format(len(common_best_combinations), best_combinations_amount))
    common_best_combinations_amounts.append(len(common_best_combinations))
    common_best_combinations_list.append(common_best_combinations_amounts)
# Out:
# HBox(children=(IntProgress(value=0, max=400), HTML(value='')))
# nns train: (920, 16)
# nns test: (116, 16)
# nns best npv combination
# NumEX:
# [  8  21  25  26  28  31  59  64  88 107]
# ML:
# [  8  21  25  28  31  64  83  88 100 107]
# Common combinations:
# 8 from 10
# nns_grp best npv combination
# NumEX:
# [  2   7  27  37  39  40  49  83  92 120]
# ML:
# [ 2  5  7 27 37 40 49 60 83 92]
# Common combinations:
# 8 from 10
# gs best npv combination
# NumEX:
# [ 3 18 20 21 22 39 40 42 43 44]
# ML:
# [ 3  6  7  9 10 15 18 20 22 40]
# Common combinations:
# 5 from 10
# gs_grp best npv combination
# NumEX:
# [  5  20  29  57  65 110 120 153 156 160]
# ML:
# [  5  20  29  65 103 110 120 153 160 203]
# Common combinations:
# 8 from 10
# nns train: (920, 16)
# nns test: (116, 16)
# nns best npv combination
# NumEX:
# [15 26 38 44 47 50 59 67 80 89]
# ML:
# [26 30 38 44 47 50 67 80 89 93]
# Common combinations:
# 8 from 10
# nns_grp best npv combination
# NumEX:
# [ 11  22  26  33  36  50  90  99 124 132]
# ML:
# [ 22  29  33  36  50  90  95  99 100 124]
# Common combinations:
# 7 from 10
# gs best npv combination
# NumEX:
# [ 2  5  8 11 14 25 37 38 40 41]
# ML:
# [ 2  5 10 11 14 25 29 34 38 44]
# Common combinations:
# 6 from 10
# gs_grp best npv combination
# NumEX:
# [ 15  32  36  53  56 127 132 144 166 167]
# ML:
# [ 15  32  56 105 132 144 148 158 159 174]
# Common combinations:
# 5 from 10
# nns train: (920, 16)
# nns test: (116, 16)
# nns best npv combination
# NumEX:
# [18 27 36 42 57 59 71 76 87 94]
# ML:
# [ 18  27  40  42  57  71  76  78  87 100]
# Common combinations:
# 7 from 10
# nns_grp best npv combination
# NumEX:
# [ 24  30  31  50  69  72  99 120 137 141]
# ML:
# [  3  24  27  31  69  82 105 120 137 141]
# Common combinations:
# 6 from 10
# gs best npv combination
# NumEX:
# [
44]
# Common combinations:
# 7 from 10
# gs_grp best npv combination
# NumEX:
# [ 45  48  98 109 110 114 159 165 181 182]
# ML:
# [ 45  48  58  98 109 110 114 143 159 182]
# Common combinations:
# 8 from 10
# nns train: (920, 16)
# nns test: (116, 16)
# nns best npv combination
# NumEX:
# [  1  22  24  50  53  63  67  78  99 100]
# ML:
# [ 12  24  38  44  50  53  63  78  99 100]
# Common combinations:
# 7 from 10
# nns_grp best npv combination
# NumEX:
# [  2  19  30  32  36  46  69  75  94 134]
# ML:
# [  2   3  19  30  36  46  69  75  94 100]
# Common combinations:
# 8 from 10
# gs best npv combination
# NumEX:
# [ 1 10 19 21 24 25 34 35 41 44]
# ML:
# [ 1  4 19 21 22 25 35 36 40 41]
# Common combinations:
# 6 from 10
# gs_grp best npv combination
# NumEX:
# [  2   6  13  22  39  77 111 115 166 201]
# ML:
# [  2   6  22  77 103 111 115 166 192 201]
# Common combinations:
# 8 from 10
# nns train: (920, 16)
# nns test: (116, 16)
# nns best npv combination
# NumEX:
# [ 13  18  28  66  67  80  92  95  97 104]
# ML:
# [ 13  28  30  37  73  80  92  97  99 104]
# Common combinations:
# 6 from 10
# nns_grp best npv combination
# NumEX:
# [15 29 43 44 63 64 92 93 94 95]
# ML:
# [ 15  24  29  43  44  64  92  93  95 129]
# Common combinations:
# 8 from 10
# gs best npv combination
# NumEX:
# [12 13 17 18 23 25 26 38 41 43]
# ML:
# [11 12 16 17 18 23 25 35 38 39]
# Common combinations:
# 6 from 10
# gs_grp best npv combination
# NumEX:
# [  0  35  55  99 100 126 136 149 158 159]
# ML:
# [  8  35  55  99 126 136 144 149 159 189]
# Common combinations:
# 7 from 10
# nns train: (920, 16)
# nns test: (116, 16)
# nns best npv combination
# NumEX:
# [ 34  35  43  45  60  69  85  91  93 100]
# ML:
# [ 15  36  38  43  69  82  85  92  93 100]
# Common combinations:
# 5 from 10
# nns_grp best npv combination
# NumEX:
# [ 32  33  37  48  54  78  96  98 113 115]
# ML:
# [  8  27  32  33  37  44  76  78 113 128]
# Common combinations:
# 5 from 10
# gs best npv combination
# NumEX:
# [ 8 12 18 20 23 29 33 36 37 38]
# ML:
# [ 6  8 12 18 20 23 29 33 37 41]
# Common combinations:
# 8 from 10
# gs_grp best npv combination
# NumEX:
# [  6  40  85 110 126 147 149 177 181 191]
# ML:
# [  6   9  40  57 101 110 141 147 177 181]
# Common combinations:
# 6 from 10
# nns train: (920, 16)
# nns test: (116, 16)
# nns best npv combination
# NumEX:
# [ 12  33  53  56  61  66  73  76 100 106]
# ML:
# [12 33 36 40 43 53 62 66 73 92]
# Common combinations:
# 5 from 10
# nns_grp best npv combination
# NumEX:
# [  1  41  46  49  60  71  85 103 127 132]
# ML:
# [  1  41  45  46  49  71  85 103 108 127]
# Common combinations:
# 8 from 10
# gs best npv combination
# NumEX:
# [ 2 10 17 23 33 34 35 36 37 43]
# ML:
# [ 2 10 11 23 24 30 33 34 37 40]
# Common combinations:
# 6 from 10
# gs_grp best npv combination
# NumEX:
# [  8  18  21  49  61  82 145 150 156 173]
# ML:
# [  8  18  21  49  80  82 138 145 156 173]
# Common combinations:
# 8 from 10
# nns train: (920, 16)
# nns test: (116, 16)
# nns best npv combination
# NumEX:
# [ 14  26  27  53  66  84  96  98 100 101]
# ML:
# [ 14  27  29  64  68  84  96  98 100 101]
# Common combinations:
# 7 from 10
# nns_grp best npv combination
# NumEX:
# [ 14  15  25  34  60  73  96 118 127 128]
# ML:
# [ 14  15  25  34  60  73  96 118 127 128]
# Common combinations:
# 10 from 10
# gs best npv combination
# NumEX:
# [ 5 10 18 24 27 30 32 37 42 43]
# ML:
# [ 5 10 12 16 18 24 27 39 40 44]
# Common combinations:
# 5 from 10
# gs_grp best npv combination
# NumEX:
# [  5  24  38  53  64 114 143 175 181 198]
# ML:
# [  5   6  24  38  53  64 114 143 153 175]
# Common combinations:
# 8 from 10
# nns train: (920, 16)
# nns test: (116, 16)
# nns best npv combination
# NumEX:
# [ 10  16  32  34  37  47  58  71  84 102]
# ML:
# [ 10  14  16  25  32  37  47  72  84 102]
# Common combinations:
# 7 from 10
# nns_grp best npv combination
# NumEX:
# [ 15  16  29  33  40  45  59  87  99 130]
# ML:
# [ 10  16  20  29  33  40  45  87  99 130]
# Common combinations:
# 8 from 10
# gs best npv combination
# NumEX:
# [16 17 20 29 32 34 36 37 38 44]
# ML:
# [ 5  7 11 16 17 23 29 32 37 38]
# Common combinations:
# 6 from 10
# gs_grp best npv combination
# NumEX:
# [  9  21 103 112 122 147 150 168 174 193]
# ML:
# [  9  21 112 122 147 150 161 168 174 181]
# Common combinations:
# 8 from 10
# nns train: (920, 16)
# nns test: (116, 16)
# nns best npv combination
# NumEX:
# [ 27  34  49  50  60  74  88  96  99 104]
# ML:
# [ 34  48  49  50  60  74  88  96  99 104]
# Common combinations:
# 9 from 10
# nns_grp best npv combination
# NumEX:
# [ 10  31  63  65  91 100 101 104 121 126]
# ML:
# [ 10  17  31  65  82  91 100 101 121 126]
# Common combinations:
# 8 from 10
# gs best npv combination
# NumEX:
# [

# Common combinations:
# 8 from 10
# nns train: (920, 16)
# nns test: (116, 16)
# nns best npv combination
# NumEX:
# [ 8 14 17 31 33 47 49 74 90 98]
# ML:
# [ 8 14 17 47 49 72 73 74 90 98]
# Common combinations:
# 8 from 10
# nns_grp best npv combination
# NumEX:
# [ 14  20  28  34  43  46  82  88  90 111]
# ML:
# [  0  14  20  34  43  46  82  88  97 111]
# Common combinations:
# 8 from 10
# gs best npv combination
# NumEX:
# [ 4  8 15 27 31 32 37 40 42 44]
# ML:
# [ 3  4  8 12 14 15 27 31 32 44]
# Common combinations:
# 7 from 10
# gs_grp best npv combination
# NumEX:
# [  8  37  42  76 104 127 138 151 170 171]
# ML:
# [  4  37  67 104 127 138 145 151 170 188]
# Common combinations:
# 6 from 10
# nns train: (920, 16)
# nns test: (116, 16)
# nns best npv combination
# NumEX:
# [10 16 17 33 39 40 42 69 70 79]
# ML:
# [ 10  17  33  39  40  42  70  79  97 103]
# Common combinations:
# 8 from 10
# nns_grp best npv combination
# NumEX:
# [  0  24  25  38  58  66  72  78  90 121]
# ML:
# [ 24  25  38  62  72  77  78  90  96 109]
# Common combinations:
# 6 from 10
# gs best npv combination
# NumEX:
# [ 0  3  9 12 14 18 21 26 36 40]
# ML:
# [ 0  8  9 12 13 14 18 25 26 38]
# Common combinations:
# 6 from 10
# gs_grp best npv combination
# NumEX:
# [  4  41  62  85 128 131 152 164 175 176]
# ML:
# [  4  41  58  61  62  85 128 152 164 176]
# Common combinations:
# 8 from 10
# nns train: (920, 16)
# nns test: (116, 16)
# nns best npv combination
# NumEX:
# [ 5 24 32 35 45 47 68 70 74 90]
# ML:
# [24 35 45 46 47 59 68 74 80 90]
# Common combinations:
# 7 from 10
# nns_grp best npv combination
# NumEX:
# [ 19  22  29  36  39  41  77  80 119 131]
# ML:
# [ 22  29  39  43  73  77  80  83 119 131]
# Common combinations:
# 7 from 10
# gs best npv combination
# NumEX:
# [ 3 14 16 19 22 24 29 32 38 39]
# ML:
# [ 3  5  9 16 18 29 32 38 43 44]
# Common combinations:
# 5 from 10
# gs_grp best npv combination
# NumEX:
# [ 25  45  68  98  99 101 169 175 179 200]
# ML:
# [  8  16  25  45  68  98 143 149 169 179]
# Common combinations:
# 6 from 10
# nns train: (920, 16)
# nns test: (116, 16)
# nns best npv combination
# NumEX:
# [16 29 33 34 46 61 67 68 90 94]
# ML:
# [ 9 16 29 33 34 46 61 63 67 94]
# Common combinations:
# 8 from 10
# nns_grp best npv combination
# NumEX:
# [ 37  38  56  60  72  89  92 100 102 122]
# ML:
# [ 13  37  38  72  89  92 100 108 117 122]
# Common combinations:
# 7 from 10
# gs best npv combination
# NumEX:
# [ 1  4  6 11 12 23 31 34 36 41]
# ML:
# [ 1  6  7 11 12 23 31 33 36 43]
# Common combinations:
# 7 from 10
# gs_grp best npv combination
# NumEX:
# [ 37  39  44  99 124 149 154 174 177 195]
# ML:
# [  8  37  44  54  99 124 149 154 177 195]
# Common combinations:
# 8 from 10
# nns train: (920, 16)
# nns test: (116, 16)
# nns best npv combination
# NumEX:
# [  6  31  49  63  65  69  72  89  93 101]
# ML:
# [12 31 45 46 58 63 65 72 89 93]
# Common combinations:
# 6 from 10
# nns_grp best npv combination
# NumEX:
# [ 11  23  25  41  57  89  91 101 108 118]
# ML:
# [  7  11  23  25  41  57  89  91 101 118]
# Common combinations:
# 9 from 10
# gs best npv combination
# NumEX:
# [ 2  4  9 12 23 35 37 38 41 44]
# ML:
# [ 2  4  9 12 20 25 32 35 37 40]
# Common combinations:
# 6 from 10
# gs_grp best npv combination
# NumEX:
# [ 25  47  60  64  95  97 146 162 175 193]
# ML:
# [ 47  60  64  95  97 130 141 146 162 175]
# Common combinations:
# 8 from 10
# nns train: (920, 16)
# nns test: (116, 16)
# nns best npv combination
# NumEX:
# [  8  10  16  24  30  76  80  89  90 106]
# ML:
# [  8  10  16  24  30  76  80  89  90 106]
# Common combinations:
# 10 from 10
# nns_grp best npv combination
# NumEX:
# [  6   7  26  32  35  59  89  96 117 131]
# ML:
# [  6   7  23  26  35  40  59  89  92 131]
# Common combinations:
# 7 from 10
# gs best npv combination
# NumEX:
# [16 22 31 36 38 39 40 41 42 44]
# ML:
# [ 6 12 22 29 31 39 40 41 42 44]
# Common combinations:
# 7 from 10
# gs_grp best npv combination
# NumEX:
# [  9  83  96  98 103 112 130 159 164 168]
# ML:
# [ 53  83  96 103 130 145 164 168 192 199]
# Common combinations:
# 6 from 10
# nns train: (920, 16)
# nns test: (116, 16)
# nns best npv combination
# NumEX:
# [ 9 18 19 33 34 72 74 82 85 87]
# ML:
# [ 9 16 18 33 43 63 74 85 87 98]
# Common combinations:
# 6 from 10
# nns_grp best npv combination
# NumEX:
# [ 12  30  50  51  78  92 101 125 129 134]
# ML:
# [ 12  30  50  51  63  69  92 101 129 134]
# Common combinations:
# 8 from 10
# gs best npv combination
# NumEX:
# [ 7 15 21 29 31 35 36 37 41 44]
# ML:
# [ 7 15 21 29 35 36 38 42 43 44]
# Common combinations:
# 7 from 10
# gs_grp best npv combination
# NumEX:
# [ 17  31  59  60  80 123 141 142 156 187]
# ML:
# [  4  17  60  75  80 123 142 156 182 184]
# Common combinations:
# 6 from 10
# nns train: (920, 16)
# nns test: (116, 16)
# nns best npv combination
# NumEX:
# [ 3  8 13 31 43 52 68 88 91 95]
# ML:
# [  3   4  13  31  43  61  75  88  95 103]
# Common combinations:
# 6 from 10
# nns_grp best npv combination
# NumEX:
# [ 11  17  33  37  41  43  60  93 119 135]
# ML:
# [ 17  27  33  37  43  79  93 100 109 135]
# Common combinations:
# 6 from 10
# gs best npv combination
# NumEX:
# [ 2  6 10 13 18 19 21 32 36 38]
# ML:
# [ 3  6 10 13 19 21 32 36 38 44]
# Common combinations:
# 8 from 10
# gs_grp best npv combination
# NumEX:
# [  4   5  10  87  89  95 130 146 154 159]
# ML:
# [  4   5  10  87  89 107 130 154 159 175]
# Common combinations:
# 8 from 10
# nns train: (920, 16)
# nns test: (116, 16)
# nns best npv combination
# NumEX:
# [  0  20  27  35  45  55  68  96  99 100]
# ML:
# [ 20  27  28  35  45  55  57  95  96 100]
# Common combinations:
# 7 from 10
# nns_grp best npv combination
# NumEX:
# [ 19  27  44  51  57  84  94 119 134 137]
# ML:
# [ 27  44  51  61  65  84  88  94 103 127]
# Common combinations:
# 5 from 10
# gs best npv combination
# NumEX:
# [ 1 16 19 28 35 37 38 40 43 44]
# ML:
# [ 1  5 16 17 19 33 37 38 40 42]
# Common combinations:
# 6 from 10
# gs_grp best npv combination
# NumEX:
# [ 16  71  96 139 146 148 165 178 188 199]
# ML:
# [ 56  71  96  97 100 119 139 146 148 163]
# Common combinations:
# 5 from 10
# nns train: (920, 16)
# nns test: (116, 16)
# nns best npv combination
# NumEX:
# [20 21 30 33 34 38 48 51 69 79]
# ML:
# [ 20  21  30  33  34  38  48  51  69 104]
# Common combinations:
# 9 from 10
# nns_grp best npv combination
# NumEX:
# [  2  21  30  32  33  44  80  91 112 129]
# ML:
# [ 13  21  30  32  33  44  91 104 112 129]
# Common combinations:
# 8 from 10
# gs best npv combination
# NumEX:
# [ 3  6 18 32 35 38 39 40 42 44]
# ML:
# [ 6  8 12 18 20 27 32 35 41 43]
# Common combinations:
# 4 from 10
# gs_grp best npv combination
# NumEX:
# [ 10  90  92 109 111 134 136 141 143 158]
# ML:
# [  4  21  74  92 109 111 136 141 142 143]
# Common combinations:
# 6 from 10
# nns train: (920, 16)
# nns test: (116, 16)
# nns best npv combination
# NumEX:
# [14 20 27 35 37 63 70 74 76 97]
# ML:
# [14 35 37 47 60 63 70 74 80 98]
# Common combinations:
# 6 from 10
# nns_grp best npv combination
# NumEX:
# [ 18  24  31  35  36  41  70 111 134 139]
# ML:
# [ 18  31  35  36  41  64  70  82 114 134]
# Common combinations:
# 7 from 10
# gs best npv combination
# NumEX:
# [ 4  5 16 23 25 26 35 36 38 42]
# ML:
# [ 5 26 29 32 35 36 37 38 39 42]
# Common combinations:
# 6 from 10
# gs_grp best npv combination
# NumEX:
# [ 26  28  32  50  69 121 171 177 189 197]
# ML:
# [ 26  59  69 107 141 146 148 171 189 197]
# Common combinations:
# 5 from 10
# nns train: (920, 16)
# nns test: (116, 16)
# nns best npv combination
# NumEX:
# [ 7 22 30 38 39 44 52 53 72 77]
# ML:
# [ 7 14 22 38 42 44 52 53 77 78]
# Common combinations:
# 7 from 10
# nns_grp best npv combination
# NumEX:
# [ 36  40  41  50  55  70  87  95 130 134]
# ML:
# [  1  35  36  40  55  65  70  87  89 130]
# Common combinations:
# 6 from 10
# gs best npv combination
# NumEX:
# [ 8  9 13 15 23 27 29 34 41 43]
# ML:
# [ 3  4  6  8 13 23 24 26 37 38]
# Common combinations:
# 3 from 10
# gs_grp best npv combination
# NumEX:
# [  2   6  10  68  77 100 131 161 180 183]
# ML:
# [  2   6  10  13 100 101 105 161 180 195]
# Common combinations:
# 6 from 10
# nns train: (920, 16)
# nns test: (116, 16)
# nns best npv combination
# NumEX:
# [17 20 26 31 38 41 53 60 72 73]
# ML:
# [17 20 26 38 53 59 60 72 73 83]
# Common combinations:
# 8 from 10
# nns_grp best npv combination
# NumEX:
# [  9  24  26  37  40  56  59  72  81 106]
# ML:
# [ 13  23  24  37  51  56  72  81 106 130]
# Common combinations:
# 6 from 10
# gs best npv combination
# NumEX:
# [ 3  9 11 17 22 27 32 41 43 44]
# ML:
# [ 3  9 11 15 17 22 27 32 38 43]
# Common combinations:
# 8 from 10
# gs_grp best npv combination
# NumEX:
# [  2  20  48  86  92  97 102 136 165 174]
# ML:
# [  2   7  20  48  86  97 102 135 136 187]
# Common combinations:
# 7 from 10
# nns train: (920, 16)
# nns test: (116, 16)
# nns best npv combination
# NumEX:
# [ 33  36  43  51  55  58  77  82  95 102]
# ML:
# [31 33 36 37 43 55 65 77 82 95]
# Common combinations:
# 7 from 10
# nns_grp best npv combination
# NumEX:
# [ 27  30  33  51  66  71  98 101 111 122]
# ML:
# [ 27  30  33  48  50  51  98 101 122 135]
# Common combinations:
# 7 from 10
# gs best npv combination
# NumEX:
# [ 2  3  8 19 21 25 34 35 39 40]
# ML:
# [ 2  3  8 13 21 25 33 34 35 37]
# Common combinations:
# 7 from 10
# gs_grp best npv combination
# NumEX:
# [  9  21  44  66  95 103 109 112 124 160]
# ML:
# [  9  44  51  66  95 103 112 140 165 174]
# Common combinations:
# 6 from 10

# %%
common_best_combinations_arr = np.array(common_best_combinations_list)

# %%
plt.figure()
plt.grid()
plt.hist(common_best_combinations_arr[:,0], bins=range(0, 11, 1),
         weights=np.ones(len(common_best_combinations_arr[:,0])),
         color='silver')
plt.xticks(range(0, best_combinations_amount+1, 1))
# plt.yticks(range(0, number_of_tests+1, 5))
plt.xlabel("Number of proper {} best combinations".format(best_combinations_amount))
plt.ylabel("Number of appearances from {} tests".format(number_of_tests))
plt.title("nns best results")
plt.savefig('nns_bests_histogram.png', format='png', dpi=300)
plt.show()

# %%
plt.figure()
plt.grid()
plt.hist(common_best_combinations_arr[:,0], bins=range(0, 11, 1),
         weights=np.ones(len(common_best_combinations_arr[:,0])),
         color='silver')
plt.xticks(range(0, best_combinations_amount+1, 1))
# plt.yticks(range(0, number_of_tests+1, 5))
plt.xlabel("Number of proper {} best combinations".format(best_combinations_amount))
plt.ylabel("Number of appearances from {} tests".format(number_of_tests))
plt.title("nns_grp best results")
plt.savefig('nns_grp_bests_histogram.png', format='png', dpi=300)
plt.show()

# %%
plt.figure()
plt.grid()
plt.hist(common_best_combinations_arr[:,0], bins=range(0, 11, 1),
         weights=np.ones(len(common_best_combinations_arr[:,0])),
         color='silver')
plt.xticks(range(0, best_combinations_amount+1, 1))
# plt.yticks(range(0, number_of_tests+1, 5))
plt.xlabel("Number of proper {} best combinations".format(best_combinations_amount))
plt.ylabel("Number of appearances from {} tests".format(number_of_tests))
plt.title("gs best results")
plt.savefig('gs_bests_histogram.png', format='png', dpi=300)
plt.show()

# %%
plt.figure()
plt.grid()
plt.hist(common_best_combinations_arr[:,0], bins=range(0, 11, 1),
         weights=np.ones(len(common_best_combinations_arr[:,0])),
         color='silver')
plt.xticks(range(0, best_combinations_amount+1, 1))
# plt.yticks(range(0, number_of_tests+1, 5))
plt.xlabel("Number of proper {} best combinations".format(best_combinations_amount))
plt.ylabel("Number of appearances from {} tests".format(number_of_tests))
plt.title("gs_grp best results")
plt.savefig('gs_grp_bests_histogram.png', format='png', dpi=300)
plt.show()
